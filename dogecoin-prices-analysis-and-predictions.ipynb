# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import statsmodels.api as sm

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
df = pd.read_csv('../input/dogecoinprices/full_data__4__2021.csv')
df.head()
# Out:
#    Unnamed: 0   timestamp  Asset_ID  Asset_Name  Weight  Count      Open  \
# 0    18935915  1609459260         4         NaN     NaN   84.0  0.004671
# 1    18935929  1609459320         4         NaN     NaN   23.0  0.004683
# 2    18935943  1609459380         4         NaN     NaN   11.0  0.004670
# 3    18935957  1609459440         4         NaN     NaN   38.0  0.004675
# 4    18935971  1609459500         4         NaN     NaN   19.0  0.004670
#
#        High       Low     Close        Volume      VWAP    Target
# 0  0.004683  0.004668  0.004677  2.202482e+06  0.004675 -0.008679
# 1  0.004686  0.004669  0.004672  6.446365e+05  0.004676 -0.006432
# 2  0.004676  0.004668  0.004672  5.196483e+05  0.004671 -0.006881
# 3  0.004682  0.004667  0.004672  7.038264e+05  0.004672 -0.007622
# 4  0.004674  0.004668  0.004671  4.305936e+05  0.004670 -0.007321

# %% [markdown]
# ## Data Preprocessing

# %%
from datetime import datetime

def return_datetime(timestamp):
    return datetime.fromtimestamp(timestamp)

df['date'] = df['timestamp'].apply(return_datetime)

# %%
cols = ['date', 'Open', 'High', 'Low', 'Close', 'Volume']
df = df[cols]
df.head()
# Out:
#                  date      Open      High       Low     Close        Volume
# 0 2021-01-01 00:01:00  0.004671  0.004683  0.004668  0.004677  2.202482e+06
# 1 2021-01-01 00:02:00  0.004683  0.004686  0.004669  0.004672  6.446365e+05
# 2 2021-01-01 00:03:00  0.004670  0.004676  0.004668  0.004672  5.196483e+05
# 3 2021-01-01 00:04:00  0.004675  0.004682  0.004667  0.004672  7.038264e+05
# 4 2021-01-01 00:05:00  0.004670  0.004674  0.004668  0.004671  4.305936e+05

# %% [markdown]
# ## Data Exploration

# %%
# Resampling to hourly frequency
df.index = df.date
df = df.resample('H').mean()

# Resampling to daily frequency
df_day = df.resample('D').mean()

# Resampling to monthly frequency
df_month = df.resample('M').mean()

# Resampling to quarterly frequency
df_Q = df.resample('Q-DEC').mean()

# %%
# PLOTS
fig = plt.figure(figsize=[15, 12])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(411)
plt.plot(df.Close, '-', label='By Hours')
plt.legend()

plt.subplot(412)
plt.plot(df_day.Close, '-', label='By Days')
plt.legend()

plt.subplot(413)
plt.plot(df_month.Close, '-', label='By Months')
plt.legend()

plt.subplot(414)
plt.plot(df_Q.Close, '-', label='By Quarters')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We will predict bitcoin prices by hours to match part 1.

# %% [markdown]
# ## Stationarity Test

# %%
# Stability Test (Dickey-Fuller Test)
def is_stationary(y, col='Close'):

    # "HO: Non-stationary"
    # "H1: Stationary"

    p_value = sm.tsa.stattools.adfuller(y)[1]
    if p_value < 0.05:
        print(F"{col} Result: Stationary (H0: non-stationary, p-value: {round(p_value, 3)})")
    else:
        print(F"{col} Result: Non-Stationary (H0: non-stationary, p-value: {round(p_value, 4)})")

# %%
# apply is_stationary
for col in df.columns:
    is_stationary(df[col], col)
# Out:
# Open Result: Non-Stationary (H0: non-stationary, p-value: 0.3136)
# High Result: Non-Stationary (H0: non-stationary, p-value: 0.3138)
# Low Result: Non-Stationary (H0: non-stationary, p-value: 0.314)
# Close Result: Non-Stationary (H0: non-stationary, p-value: 0.3138)
# Volume Result: Stationary (H0: non-stationary, p-value: 0.0)

# %% [markdown]
# only **Volume** seems to be **Stationary.**

# %%
# Time Series Components and Stationarity Test
def ts_decompose(y, model="additive", stationary=False):
    result = sm.tsa.seasonal_decompose(y, model=model)
    fig, axes = plt.subplots(4, 1, sharex=True, sharey=False)
    fig.set_figheight(10)
    fig.set_figwidth(15)

    axes[0].set_title("Decomposition for " + model + " model")
    axes[0].plot(y, 'k', label='Original ' + model)
    axes[0].legend(loc='upper left')

    axes[1].plot(result.trend, label='Trend')
    axes[1].legend(loc='upper left')

    axes[2].plot(result.seasonal, 'g', label='Seasonality & Mean: ' + str(round(result.seasonal.mean(), 4)))
    axes[2].legend(loc='upper left')

    axes[3].plot(result.resid, 'r', label='Residuals & Mean: ' + str(round(result.resid.mean(), 4)))
    axes[3].legend(loc='upper left')
    plt.show(block=True)

    if stationary:
        is_stationary(y)

# %%
# apply test decompose for volume
ts_decompose(df.Volume[:1000], stationary=True)
# Out:
# Close Result: Stationary (H0: non-stationary, p-value: 0.003)

# %%
# Analysis for additive and multiplicative models
for model in ["additive", "multiplicative"]:
    ts_decompose(df.Close, model)

# %% [markdown]
# As Target **Non-Stationary**, We have to do some normalization and test it again.

# %% [markdown]
# ## Data Normalize

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))

target = scaler.fit_transform(df[['Close']])

df['Close_norm'] = target 
df['Close_diff'] = df['Close_norm'].diff()
df.fillna(0, inplace=True)

# %%
# apply is_stationary
is_stationary(df.Close_diff)
# Out:
# Close Result: Stationary (H0: non-stationary, p-value: 0.0)

# %%
# show 512 sample
ts_decompose(df.Close_diff[:512], stationary=True)
# Out:
# Close Result: Stationary (H0: non-stationary, p-value: 0.0)

# %% [markdown]
# Now the data is ready for Modeling

# %% [markdown]
# ## Model

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

from tensorflow.keras.optimizers import SGD, Adam

# %% [markdown]
# ### Prepare Data

# %%
train_split = 0.9
data_len = int(target.shape[0] * train_split)

train_target = target[:data_len]
test_target = target[data_len:]

# %% [markdown]
# ### Add TimeStamp

# %%
sr = 1
lb = 72*sr # hours

train_gen = TimeseriesGenerator(train_target, train_target, length=lb, sampling_rate=sr, batch_size=256)
test_gen = TimeseriesGenerator(test_target, test_target, length=lb, sampling_rate=sr, batch_size=128)

shape = train_gen[0][0].shape[1:]

# %% [markdown]
# ### LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=shape))
model.add(LSTM(4))
model.add(Dense(1,))

# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 72, 32)            4352
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 592
# _________________________________________________________________
# dense (Dense)                (None, 1)                 5
# =================================================================
# Total params: 4,949
# Trainable params: 4,949
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model callbacks
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)
reduce_lr = LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x)

# loss function
huber_loss = tf.keras.losses.Huber()
model.compile(loss='mse', optimizer=Adam(learning_rate=0.1))

# Traning
history = model.fit(train_gen, 
                    validation_data=test_gen, 
                    callbacks=[es, reduce_lr],
                    epochs=1000,
                    verbose=1,
                   )
# Out:
# Epoch 1/1000
# 28/28 [==============================] - 5s 32ms/step - loss: 0.0892 - val_loss: 0.0273
# Epoch 2/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 5.0941e-04
# Epoch 3/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 6.3345e-04
# Epoch 4/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 6.3265e-04
# Epoch 5/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 5.8624e-04
# Epoch 6/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 5.6039e-04
# Epoch 7/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 5.5456e-04
# Epoch 8/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 6.0304e-04
# Epoch 9/1000
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 4.9507e-04
# Epoch 10/1000
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 4.7802e-04
# Epoch 11/1000
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0017 - val_loss: 4.5718e-04
# Epoch 12/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 4.6512e-04
# Epoch 13/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 4.3744e-04
# Epoch 14/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 4.5299e-04
# Epoch 15/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 4.4078e-04
# Epoch 16/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 4.3301e-04
# Epoch 17/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 4.2165e-04
# Epoch 18/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 4.1049e-04
# Epoch 19/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 4.1327e-04
# Epoch 20/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 4.3856e-04
# Epoch 21/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 4.0450e-04
# Epoch 22/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.1115e-04
# Epoch 23/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0782e-04
# Epoch 24/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0603e-04
# Epoch 25/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0592e-04
# Epoch 26/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0411e-04
# Epoch 27/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 3.9766e-04
# Epoch 28/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0521e-04
# Epoch 29/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 4.0002e-04
# Epoch 30/1000
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 4.0145e-04
# Epoch 31/1000
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 4.0197e-04
# Epoch 32/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9696e-04
# Epoch 33/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9446e-04
# Epoch 34/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9567e-04
# Epoch 35/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9709e-04
# Epoch 36/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9697e-04
# Epoch 37/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9544e-04
# Epoch 38/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9555e-04
# Epoch 39/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9445e-04
# Epoch 40/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9193e-04
# Epoch 41/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9446e-04
# Epoch 42/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9410e-04
# Epoch 43/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9474e-04
# Epoch 44/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9394e-04
# Epoch 45/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9236e-04
# Epoch 46/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9348e-04
# Epoch 47/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9274e-04
# Epoch 48/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9379e-04
# Epoch 49/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9342e-04
# Epoch 50/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9297e-04
# Epoch 51/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9259e-04
# Epoch 52/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9292e-04
# Epoch 53/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9224e-04
# Epoch 54/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9234e-04
# Epoch 55/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9260e-04
# Epoch 56/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9225e-04
# Epoch 57/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9278e-04
# Epoch 58/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9271e-04
# Epoch 59/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9237e-04
# Epoch 60/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9256e-04
# Epoch 61/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9233e-04
# Epoch 62/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9267e-04
# Epoch 63/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9242e-04
# Epoch 64/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9245e-04
# Epoch 65/1000
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 3.9214e-04
# Epoch 66/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9252e-04
# Epoch 67/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9249e-04
# Epoch 68/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9231e-04
# Epoch 69/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9213e-04
# Epoch 70/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9237e-04
# Epoch 71/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9227e-04
# Epoch 72/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9237e-04
# Epoch 73/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9233e-04
# Epoch 74/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9232e-04
# Epoch 75/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9220e-04
# Epoch 76/1000
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 3.9222e-04
# Epoch 77/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9220e-04
# Epoch 78/1000
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 3.9227e-04
# Epoch 79/1000
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 3.9224e-04
# Epoch 80/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9224e-04
# Epoch 81/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9217e-04
# Epoch 82/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9220e-04
# Epoch 83/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9220e-04
# Epoch 84/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9219e-04
# Epoch 85/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9220e-04
# Epoch 86/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9223e-04
# Epoch 87/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9218e-04
# Epoch 88/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9219e-04
# Epoch 89/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9217e-04
# Epoch 90/1000
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 3.9219e-04
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping

# %% [markdown]
# ### Test Model

# %%
# summarize history for loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(f"Model Loss\n Error: [{np.min(history.history['val_loss'])}]")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Predictions

# %%
# predict and compare
pred = scaler.inverse_transform(model.predict(test_gen))
true = scaler.inverse_transform(test_target[lb:])

print('Real Mean-Aabsolute-Error:', np.mean(abs(pred-true)))
# Out:
# Real Mean-Aabsolute-Error: 0.003987378580480597

# %%
# plot the results
plt.figure(figsize=(12, 6))
plt.plot(true, label='True');
plt.plot(pred, label='Pred')
plt.title('Normal Dogecion-Prices Predictions', fontsize=14)
plt.legend();

# %% [markdown]
# ## Conclusion:
#
# The Real Mean-Aabsolute-Error is reasonable, and predictions fit well.
